# %% [markdown]
# <a href="https://colab.research.google.com/github/SM-30/IPV/blob/main/mBART50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.4 MB 4.3 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 32.9 MB/s
# ...
#      |████████████████████████████████| 596 kB 73.7 MB/s
# ...
#      |████████████████████████████████| 101 kB 10.8 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# !pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.2 MB 3.7 MB/s
# ...

# %%
from transformers import MBartForConditionalGeneration , MBart50TokenizerFast

# %%
model_name = "facebook/mbart-large-50-many-to-many-mmt"
model = MBartForConditionalGeneration.from_pretrained(model_name)
tokenizer = MBart50TokenizerFast.from_pretrained(model_name)
# Out:
# Downloading:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.28G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/529 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.83M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/649 [00:00<?, ?B/s]

# %% [markdown]
# Go to this link : https://huggingface.co/facebook/mbart-large-50-many-to-many-mmt
#
# Scroll down and there you'll find all the languages covered select the language code from there.

# %%
text = "סעיף ב. כל אדם זכאי לזכויות ולחרויות שנקבעו בהכרזש זו ללא הפליה כלשהיא מטעמי גזע, צבע, מין, לשון, דח, דעה פוליטית או דעה בבעיות אחרות, בגלל מוצא לאומי או חברתי, קנין, לידה או מעמד אחר. גדולה מזו, לא יופלה אדם על פי מעמדה המדיני, על פי סמכותה או על פי מעמדה הבינלאומי של המדינה או הארץ שאליה הוא שייך, דין שהארץ היא עצמאית, ובין שהיא נתונה לנאמנות, בין שהיא נטולת שלטון עצמי ובין שריבונותה מוגבלת כל הגבלה אחרת." #Text that we want to translate
tokenizer.src_lang = "he_IL" #Language code of the text that we want to translate

# %%
model_inputs = tokenizer(text, return_tensors = "pt")
generated_tokens = model.generate(**model_inputs, forced_bos_token_id = tokenizer.lang_code_to_id["en_XX"]) # here inside the quotes enter the code of language that you want to translate to.
translation  = tokenizer.batch_decode(generated_tokens, skip_special_tokens = True)

# %%
translation
# Out:
# ['Section B: Any person shall be entitled to the rights and freedoms set forth in this charter without any discrimination on grounds of race, color, sex, language, religion, political or other opinion, national or social origin, Kenya, birth or any other status, and above all, shall not be deprived by reason of his or her political standing, by reason of his or her authority or by reason of the international standing of the country or country to which he or she belongs, by reason that the country is independent, by reason that it is a party to a treaty, by reason that it is not self-governing and by reason that its sovereignty is limited by any other constraint.']
